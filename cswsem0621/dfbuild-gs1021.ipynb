# %%
from glob import glob as glob
import pandas as pd
import numpy as np

# %%
fL = glob('data/gs1021/rawacc/acc-*')
for f in fL:
  accseeds = np.load(f) # cond,seed,trials
  acc = accseeds.mean(1)
  paramD = {}
  param_names = ['alpha','betawi','betabt','lmda']
  param_vals = [i.split('_')[-1] for i in f.split('/')[-1].split('-')[1:]][:4]
  paramD = {**paramD,**dict(zip(param_names,param_vals))}
paramD
condL = ['blocked','interleaved','early','middle','late']
acc.shape
for ci in range(len(condL)):
  acc_c = acc[ci]
dict(zip(range(200),acc_c))
# Out:
# {0: 0.5,
#  1: 0.5,
#  2: 0.5,
#  3: 0.5,
#  4: 0.5,
#  5: 0.5,
#  6: 0.5,
#  7: 0.5,
#  8: 0.5,
#  9: 0.5,
#  10: 0.5,
#  11: 0.5,
#  12: 0.5,
#  13: 0.5,
#  14: 0.5,
#  15: 0.5,
#  16: 0.5,
#  17: 0.5,
#  18: 0.5,
#  19: 0.5,
#  20: 0.5,
#  21: 0.5,
#  22: 0.5,
#  23: 0.5,
#  24: 0.5,
#  25: 0.5,
#  26: 0.5,
#  27: 0.5,
#  28: 0.5,
#  29: 0.5,
#  30: 0.5,
#  31: 0.5,
#  32: 0.5,
#  33: 0.5,
#  34: 0.5,
#  35: 0.5,
#  36: 0.5,
#  37: 0.5,
#  38: 0.5,
#  39: 0.5,
#  40: 0.5,
#  41: 0.5,
#  42: 0.5,
#  43: 0.5,
#  44: 0.5,
#  45: 0.5,
#  46: 0.5,
#  47: 0.5,
#  48: 0.5,
#  49: 0.5,
#  50: 0.5,
#  51: 0.5,
#  52: 0.5,
#  53: 0.5,
#  54: 0.5,
#  55: 0.5,
#  56: 0.5,
#  57: 0.5,
#  58: 0.5,
#  59: 0.5,
#  60: 0.5,
#  61: 0.5,
#  62: 0.5,
#  63: 0.5,
#  64: 0.5,
#  65: 0.5,
#  66: 0.5,
#  67: 0.5,
#  68: 0.5,
#  69: 0.5,
#  70: 0.5,
#  71: 0.5,
#  72: 0.5,
#  73: 0.5,
#  74: 0.5,
#  75: 0.5,
#  76: 0.5,
#  77: 0.5,
#  78: 0.5,
#  79: 0.5,
#  80: 0.5,
#  81: 0.6530622442933217,
#  82: 0.6819571286444124,
#  83: 0.7013462966909145,
#  84: 0.7644017856825923,
#  85: 0.7557121442124971,
#  86: 0.8208568622848464,
#  87: 0.7738599463306005,
#  88: 0.7822097264219936,
#  89: 0.8363395207566262,
#  90: 0.8465018508446431,
#  91: 0.8073766675864633,
#  92: 0.8496095828368102,
#  93: 0.8455323541528837,
#  94: 0.8384794192484057,
#  95: 0.8381022232110635,
#  96: 0.8612778442461599,
#  97: 0.849663103683774,
#  98: 0.8532215899377451,
#  99: 0.8641503149613768,
#  100: 0.8742445938781418,
#  101: 0.8365488493157633,
#  102: 0.8294330316779139,
#  103: 0.8474762276316938,
#  104: 0.8935050663216706,
#  105: 0.8493556041010609,
#  106: 0.8422231926432034,
#  107: 0.850044879608352,
#  108: 0.8424579345052307,
#  109: 0.8325032181664832,
#  110: 0.8526529925840817,
#  111: 0.8704200374993316,
#  112: 0.8523580782922899,
#  113: 0.8353512915540926,
#  114: 0.8795751305602966,
#  115: 0.8720274476146489,
#  116: 0.8633035817173131,
#  117: 0.8533583432400041,
#  118: 0.8639002106752389,
#  119: 0.871880702629009,
#  120: 0.22547066497396837,
#  121: 0.1681683216429073,
#  122: 0.2252637175763698,
#  123: 0.22739808941041278,
#  124: 0.23925462627306682,
#  125: 0.23126289720376358,
#  126: 0.209480075154023,
#  127: 0.22408678996581696,
#  128: 0.22525438685464685,
#  129: 0.25348151407453134,
#  130: 0.2358067822591776,
#  131: 0.22251622751858702,
#  132: 0.22759182012974447,
#  133: 0.21171224118771484,
#  134: 0.23782525046744088,
#  135: 0.2383631115242354,
#  136: 0.21118823998082437,
#  137: 0.2244267626016699,
#  138: 0.23662068370772524,
#  139: 0.23472238417704727,
#  140: 0.2403133396701138,
#  141: 0.21647121819934562,
#  142: 0.23583489721800405,
#  143: 0.22967282872680295,
#  144: 0.24720544286148233,
#  145: 0.23308752128588872,
#  146: 0.22563280833254232,
#  147: 0.21493101113658714,
#  148: 0.22971571263582444,
#  149: 0.24625004683766163,
#  150: 0.2167937227171479,
#  151: 0.24608401839043587,
#  152: 0.24786212963502988,
#  153: 0.25460832581559684,
#  154: 0.2721829498524993,
#  155: 0.2785062293944677,
#  156: 0.2990408722527577,
#  157: 0.3026798898894704,
#  158: 0.3119650062439949,
#  159: 0.3216463984926159,
#  160: 0.4621016201773015,
#  161: 0.6011332044080602,
#  162: 0.4825845335413977,
#  163: 0.48265200832495714,
#  164: 0.4970260331774046,
#  165: 0.4840490214940369,
#  166: 0.5493527420765072,
#  167: 0.5118532136315221,
#  168: 0.528271971365744,
#  169: 0.5588026364885832,
#  170: 0.4928626848766677,
#  171: 0.5329004663278458,
#  172: 0.5145394459938555,
#  173: 0.5465336310248436,
#  174: 0.4924892884986406,
#  175: 0.4570031410554226,
#  176: 0.5268223312019872,
#  177: 0.5584646975446235,
#  178: 0.4984694855313033,
#  179: 0.5479829309239983,
#  180: 0.5744626088350627,
#  181: 0.4784939788115446,
#  182: 0.5131046832901375,
#  183: 0.5618361989449644,
#  184: 0.48824146340449714,
#  185: 0.48124580901017283,
#  186: 0.5197075487091496,
#  187: 0.5571589637688469,
#  188: 0.4621193207097605,
#  189: 0.5431153972936895,
#  190: 0.5445709469610839,
#  191: 0.5023033764556782,
#  192: 0.48295008747185053,
#  193: 0.4622525718012225,
#  194: 0.5573486138539908,
#  195: 0.45436615070441067,
#  196: 0.4874346030541151,
#  197: 0.47173831036322256,
#  198: 0.5090058181852841,
#  199: 0.45383797749516647}

# %%
dict?
