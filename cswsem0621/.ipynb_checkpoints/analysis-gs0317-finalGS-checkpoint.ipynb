# %%
from matplotlib import pyplot as plt
from scipy.special import softmax
from itertools import product
import numpy as np
##
from utils import *
from model import *
from analysis import *
##
import time
import seaborn as sns
from glob import glob as glob
sns.set_context('talk')

# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
## separated acc2/3
gsname = 'gs0317'

# %% [markdown]
# ### load data

# %%
gsdf = pd.read_csv('data/%s-summdf.csv'%gsname).astype(float)
gsdf.loc[:,"mse-bi"] = gsdf.b_mse1+gsdf.b_mse2+gsdf.i_mse1+gsdf.i_mse2

# %%
# ## load human data
# hdf = pd.read_csv('../human_data.csv')
# humanD = {}
# for c in ['blocked','interleaved','early','middle','late']:
#   humanD[c[0]] = hdf.loc[:,('%s mean')%c].values.T[-40:].mean()
# ## test acc: difference to human
# for c in ['b','i','e','m','l']:
#   gsdf['%s-test_diff'%c] = np.abs(gsdf.loc[:,'testacc-%s'%c] - humanD[c])
# ## block+interleaved mse
# gsdf.loc[:,'mse-bi'] = gsdf.loc[:,'mse-i']+gsdf.loc[:,'mse-b']

# %% [markdown]
# ### plt single condition

# %%
def save_and_close(param_str,rank,mse):
  plt.title(param_str[:120])
  plt.savefig("figures/top40/%s-%i-mse%.3f-%s.png"%(gsname,rank,mse,param_str))
  plt.close('all')
  
def pipeline(row,ns=50):
  """ 
  each step of the pipeline involves 
    running a csw experiment on a param contained in row
    calculating a metric on exp_batch_data
    plotting and saving
  """
  mse = dict(row)['mse-bi'].round(3)
  ## RUN EXP
  args,paramstr = get_argsD(row)
  args['sem']['skipt1']=True
  exp_batch_data = run_batch_exp_curr(ns,args,condL) # [curr],[seeds],{data}
#   print(len(exp_batch_data),len(exp_batch_data[0]))
#   print(exp_batch_data[0][0].keys())
  ## ACCURACY
  plt_acc(exp_batch_data)
  save_and_close("acc-%s"%paramstr,rank,mse)
  ## LC COUNTS VIOLIN
  plt_LC_violins(exp_batch_data)
  save_and_close("lc-%s"%paramstr,rank,mse)
  ## ajdusted rand
  plt_arscores(exp_batch_data)
  save_and_close("ar-%s"%paramstr,rank,mse)

# %% [markdown]
# # top 40 MSE analyses

# %%
TOP_K = 40
## select top40 MSE
topKgsdf = gsdf.sort_values('mse-bi').iloc[:TOP_K]
topKgsdf
# Out:
#     Unnamed: 0  concentration  stickiness_wi  stickiness_bt  sparsity  pvar  \
# 34         0.0      63.275577      79.876714      79.876714  1.100756   0.0
# 16         0.0      79.950821      79.154049      79.154049  1.084087   0.0
# 21         0.0      99.014268      98.678706      98.678706  0.957709   0.0
# 33         0.0      62.539810      67.866690      67.866690  0.881855   0.0
# 14         0.0      52.252028      54.615926      54.615926  0.795325   0.0
# 15         0.0      75.252230      97.952158      97.952158  0.876449   0.0
# 29         0.0      43.637712      42.815672      42.815672  0.862996   0.0
# 10         0.0      30.781833      45.226696      45.226696  0.822772   0.0
# 17         0.0      80.545466      82.243297      82.243297  0.775418   0.0
# 19         0.0      91.842775      94.544799      94.544799  0.730736   0.0
# 5          0.0      56.447562      67.335899      67.335899  0.712942   0.0
# 31         0.0      69.013765      85.268228      85.268228  0.680265   0.0
# 13         0.0      48.695290      62.157587      62.157587  0.422037   0.0
# 30         0.0      55.006446      83.414259      83.414259  0.363946   0.0
# 32         0.0      71.155516      97.396816      97.396816  0.288249   0.0
# 18         0.0      86.047240      86.917557      86.917557  0.218454   0.0
# 35         0.0      73.101443      81.388913      81.388913  0.207834   0.0
# 25         0.0      22.119220      32.300322      32.300322  0.700213   0.0
# 20         0.0      91.869032      95.385011      95.385011  0.096509   0.0
# 12    1.0     1.0         1.0     1.0  0.014271  0.006257  0.020605  0.034967
# 3     1.0     1.0         1.0     1.0  0.016269  0.007296  0.023102  0.029561
# 24    1.0     1.0         1.0     1.0  0.017002  0.007890  0.022949  0.029497
# 23    1.0     1.0         1.0     1.0  0.016466  0.007553  0.018859  0.035089
# 0     1.0     1.0         1.0     1.0  0.017241  0.007807  0.024493  0.030339
# 6     1.0     1.0         1.0     1.0  0.014649  0.006449  0.028098  0.032925
# 7     1.0     1.0         1.0     1.0  0.016087  0.007083  0.030140  0.034516
# 22    1.0     1.0         1.0     1.0  0.017362  0.008076  0.036063  0.038087
#
#       mse-bi
# 34  0.063678
# 16  0.063795
# 21  0.063850
# 33  0.064275
# 14  0.064317
# 15  0.064958
# 29  0.064983
# 10  0.065142
# 17  0.065214
# 19  0.065308
# 5   0.065402
# 31  0.065440
# 13  0.067074
# 30  0.067142
# 32  0.067670
# 18  0.068163
# 35  0.068756
# 25  0.068994
# 20  0.069577
# 28  0.070039
# 11  0.070475
# 27  0.070666
# 2   0.071014
# 1   0.071133
# 26  0.071775
# 9   0.072151
# 8   0.075354
# 4   0.075906
# 12  0.076101
# 3   0.076228
# 24  0.077337
# 23  0.077967
# 0   0.079879
# 6   0.082121
# 7   0.087826
# 22  0.099587

# %%
## LOOP
for rank,(idx,row) in enumerate(topKgsdf.iterrows()):
  print(rank)
  pipeline(row,ns=50)
# Out:
# 0
# 1
# 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-2617d18567e3> in <module>
#       2 for rank,(idx,row) in enumerate(topKgsdf.iterrows()):
#       3   print(rank)
# ----> 4   pipeline(row,ns=2)
#
# <ipython-input-5-183618c63ef4> in pipeline(row, ns)
#      15   args,paramstr = get_argsD(row)
#      16   args['sem']['skipt1']=True
# ---> 17   exp_batch_data = run_batch_exp_curr(ns,args,condL) # [curr],[seeds],{data}
#      18 #   print(len(exp_batch_data),len(exp_batch_data[0]))
#      19 #   print(exp_batch_data[0][0].keys())
#
# ~/wd/csw/cswsem0621/utils.py in run_batch_exp_curr(ns, args, currL)
#     117     args['exp']['condition'] = curr
#     118     ## extract other data here
# --> 119     data_batch = run_batch_exp(ns,args)
#     120     dataL.append(data_batch)
#     121     # dataD[curr] = dataL
#
# ~/wd/csw/cswsem0621/utils.py in run_batch_exp(ns, args)
#     135     sem = SEM(schargs=args['sch'],**args['sem'])
#     136     exp,curr  = task.generate_experiment(**args['exp'])
# --> 137     data = sem.run_exp(exp)
#     138     data['exp']=exp
#     139     dataL.append(data)
#
# ~/wd/csw/cswsem0621/model.py in run_exp(self, exp)
#     165                     xth = self.predict(xtm,schtm.schidx,schtrm.schidx)
#     166                 else:
# --> 167                     xth = scht.predict(xtm)
#     168                 ## prediction: only active schema
#     169                 # xth = scht.predict(xtm)
#
# ~/wd/csw/cswsem0621/model.py in predict(self, xtm1)
#      59     def predict(self,xtm1):
#      60         """ returns un-normalized count """
# ---> 61         xthat = np.array([
#      62             self.get_like(xtm1,x) for x in range(NSTATES)
#      63             ])
#
# ~/wd/csw/cswsem0621/model.py in <listcomp>(.0)
#      60         """ returns un-normalized count """
#      61         xthat = np.array([
# ---> 62             self.get_like(xtm1,x) for x in range(NSTATES)
#      63             ])
#      64         return xthat
#
# ~/wd/csw/cswsem0621/model.py in get_like(self, xtm1, xt)
#      45         PARAM_S = 2
#      46         num = self.lmbda + self.Tmat[xtm1,xt]
# ---> 47         den = (PARAM_S*self.lmbda) + self.Tmat[xtm1,:].sum()
#      48         like = num/den
#      49         return like
#
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      45 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      46          initial=_NoValue, where=True):
# ---> 47     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      48
#      49 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# KeyboardInterrupt:
