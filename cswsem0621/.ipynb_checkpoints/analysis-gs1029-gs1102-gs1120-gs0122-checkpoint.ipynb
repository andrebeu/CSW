# %%
from matplotlib import pyplot as plt
from scipy.special import softmax
from itertools import product
import numpy as np
from utils import *
from model import *
import time
import seaborn as sns
from glob import glob as glob
sns.set_context('talk')

# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
gsname = 'gs0125'

# %% [markdown]
# ### load data

# %%
# ## run make_df-1102.py to make dfs
# datadf = datadf1 = pd.read_csv('data/%s-datadf-1.csv'%gsname)
datadf = datadf1 = pd.read_csv('data/%s-datadf-0.csv'%gsname)

# %%
gsdf = pd.read_csv('data/%s-summdf.csv'%gsname).astype(float)
gsdf
# Out:
#        Unnamed: 0  concentration  stickiness_wi  stickiness_bt  sparsity  \
# 0             0.0       1.976717      57.178599      22.145210  0.014705
# 1             0.0       3.734488      45.940628       1.891803  0.238843
# 2             0.0       5.943099      86.182363       9.397271  0.247563
# 3             0.0       7.406883      27.023398      32.338947  0.125928
# 4             0.0       7.889096      32.754821      64.515102  0.023696
# ...           ...            ...            ...            ...       ...
# 87035         0.0      85.736730      92.535061      91.735113  0.933509
# 87036         0.0      85.817488      88.752382      75.376124  0.031421
# 87037         0.0      86.268014      94.500353      82.086820  0.460401
# 87038         0.0      90.304621      96.953251      97.415723  0.328305
# 87039         0.0      91.836294      97.121182      93.783994  0.869620
#
#        pvar  lrate  lratep  decay_rate  skipt1  ...     mse-e  testacc-i  \
# 0       0.0    1.0     1.0         1.0     1.0  ...  0.012447   0.981967
# 1       0.0    1.0     1.0         1.0     1.0  ...  0.011751   0.981242
# 2       0.0    1.0     1.0         1.0     1.0  ...  0.011735   0.913085
# 3       0.0    1.0     1.0         1.0     1.0  ...  0.012101   0.911016
# 4       0.0    1.0     1.0         1.0     1.0  ...  0.012417   0.925159
# ...     ...    ...     ...         ...     ...  ...       ...        ...
# 87035   0.0    1.0     1.0         1.0     1.0  ...  0.010199   0.609444
# 87036   0.0    1.0     1.0         1.0     1.0  ...  0.012451   0.645121
# 87037   0.0    1.0     1.0         1.0     1.0  ...  0.011245   0.629911
# 87038   0.0    1.0     1.0         1.0     1.0  ...  0.011506   0.635120
# 87039   0.0    1.0     1.0         1.0     1.0  ...  0.010255   0.608386
#
#          acc2-i     mse-i  testacc-l    acc2-l     mse-l  testacc-m    acc2-m  \
# 0      0.981861  0.127212   0.981967  0.981860  0.076899   0.981967  0.981893
# 1      0.979453  0.125039   0.981245  0.979428  0.074746   0.981243  0.980015
# 2      0.500000  0.028963   0.980526  0.500000  0.037635   0.980970  0.950736
# 3      0.500000  0.028939   0.981265  0.500000  0.038420   0.981485  0.954473
# 4      0.500000  0.030134   0.981874  0.500000  0.038982   0.981915  0.957310
# ...         ...       ...        ...       ...       ...        ...       ...
# 87035  0.500000  0.013818   0.976116  0.500000  0.033525   0.977935  0.927765
# 87036  0.500000  0.013717   0.981828  0.500000  0.038973   0.981883  0.957108
# 87037  0.500000  0.013862   0.979190  0.500000  0.036309   0.980055  0.943671
# 87038  0.500000  0.013713   0.980024  0.500000  0.037139   0.980632  0.948107
# 87039  0.500000  0.013854   0.976571  0.500000  0.033960   0.978234  0.929916
#
#           mse-m
# 0      0.101764
# 1      0.099772
# 2      0.067283
# 3      0.068148
# 4      0.069044
# ...         ...
# 87035  0.061867
# 87036  0.068955
# 87037  0.065487
# 87038  0.066618
# 87039  0.062309
#
# [87040 rows x 25 columns]

# %%
## human data
hdf = pd.read_csv('../human_data.csv')
humanD = {}
for c in ['blocked','interleaved','early','middle','late']:
  humanD[c[0]] = hdf.loc[:,('%s mean')%c].values.T[-40:].mean()
## difference to human
for c in ['b','i','e','m','l']:
  gsdf['%s-test_diff'%c] = np.abs(gsdf.loc[:,'testacc-%s'%c] - humanD[c])

# %%
# datadf.columns
# paramL = ['concentration', 'stickiness_wi', 'stickiness_bt',
#        'sparsity', 'pvar', 'lrate', 'lratep', 'decay_rate']

# %%
gsdf
# Out:
#        Unnamed: 0  concentration  stickiness_wi  stickiness_bt  sparsity  \
# 0             0.0       1.976717      57.178599      22.145210  0.014705
# 1             0.0       3.734488      45.940628       1.891803  0.238843
# 2             0.0       5.943099      86.182363       9.397271  0.247563
# 3             0.0       7.406883      27.023398      32.338947  0.125928
# 4             0.0       7.889096      32.754821      64.515102  0.023696
# ...           ...            ...            ...            ...       ...
# 87035         0.0      85.736730      92.535061      91.735113  0.933509
# 87036         0.0      85.817488      88.752382      75.376124  0.031421
# 87037         0.0      86.268014      94.500353      82.086820  0.460401
# 87038         0.0      90.304621      96.953251      97.415723  0.328305
# 87039         0.0      91.836294      97.121182      93.783994  0.869620
#
#        pvar  lrate  lratep  decay_rate  skipt1  ...    acc2-l     mse-l  \
# 0       0.0    1.0     1.0         1.0     1.0  ...  0.981860  0.076899
# 1       0.0    1.0     1.0         1.0     1.0  ...  0.979428  0.074746
# 2       0.0    1.0     1.0         1.0     1.0  ...  0.500000  0.037635
# 3       0.0    1.0     1.0         1.0     1.0  ...  0.500000  0.038420
# 4       0.0    1.0     1.0         1.0     1.0  ...  0.500000  0.038982
# ...     ...    ...     ...         ...     ...  ...       ...       ...
# 87035   0.0    1.0     1.0         1.0     1.0  ...  0.500000  0.033525
# 87036   0.0    1.0     1.0         1.0     1.0  ...  0.500000  0.038973
# 87037   0.0    1.0     1.0         1.0     1.0  ...  0.500000  0.036309
# 87038   0.0    1.0     1.0         1.0     1.0  ...  0.500000  0.037139
# 87039   0.0    1.0     1.0         1.0     1.0  ...  0.500000  0.033960
#
#        testacc-m    acc2-m     mse-m  b-test_diff  i-test_diff  e-test_diff  \
# 0       0.981967  0.981893  0.101764     0.068557     0.332779     0.073835
# 1       0.981243  0.980015  0.099772     0.067829     0.332054     0.073108
# 2       0.980970  0.950736  0.067283     0.067804     0.263897     0.073078
# 3       0.981485  0.954473  0.068148     0.068202     0.261828     0.073477
# 4       0.981915  0.957310  0.069044     0.068529     0.275971     0.073806
# ...          ...       ...       ...          ...          ...          ...
# 87035   0.977935  0.927765  0.061867     0.065512     0.039744     0.070787
# 87036   0.981883  0.957108  0.068955     0.068504     0.004067     0.073781
# 87037   0.980055  0.943671  0.065487     0.067096     0.019277     0.072381
# 87038   0.980632  0.948107  0.066618     0.067539     0.014068     0.072814
# 87039   0.978234  0.929916  0.062309     0.065716     0.040802     0.071003
#
#        m-test_diff  l-test_diff
# 0         0.291629     0.239192
# 1         0.290905     0.238470
# 2         0.290633     0.237752
# 3         0.291147     0.238491
# 4         0.291578     0.239099
# ...            ...          ...
# 87035     0.287598     0.233342
# 87036     0.291546     0.239054
# 87037     0.289718     0.236416
# 87038     0.290295     0.237250
# 87039     0.287897     0.233797
#
# [87040 rows x 30 columns]

# %%
gsdf.loc[:,'mse-bi'] = gsdf.loc[:,'mse-i']+gsdf.loc[:,'mse-b']

# %% [markdown]
# ### compute df metrics, form summary df

# %%
# subset of dataframe containing relevant params
Btest = gsdf.loc[:,'testacc-b'] > 0.95
Itest1 = gsdf.loc[:,'testacc-i'] > 0.6
Itest2 = gsdf.loc[:,'testacc-i'] < 0.65
Etest = gsdf.loc[:,'testacc-e'] > 0.8
Mtest = gsdf.loc[:,'testacc-m'] < 0.9
Mtest2 = gsdf.loc[:,'testacc-m'] < 0.85
Ltest = gsdf.loc[:,'testacc-l'] < 0.9
Iblock2 = gsdf.loc[:,'acc2-i'] > 0.51
skipt1 = gsdf.loc[:,'skipt1'] == 0
MItest = gsdf.loc[:,'testacc-m'] - gsdf.loc[:,'testacc-i'] > 0.1
LItest = gsdf.loc[:,'testacc-l'] - gsdf.loc[:,'testacc-i'] > 0.1

C = Btest&Mtest&Ltest
sgsdf = gsdf[C]
sgsdf = sgsdf.sort_values('testacc-l',ascending=False)
sgsdf
# Out:
#        Unnamed: 0  concentration  stickiness_wi  stickiness_bt  sparsity  \
# 2757          0.0       3.365310       2.319271      21.830234  0.105437
# 36139         0.0       4.526322       3.279638      92.135099  0.029242
# 25531         0.0       3.737836       2.475622      31.705909  0.004894
# 47373         0.0       4.702049       3.286470       6.198047  0.221435
# 28689         0.0       1.722058       1.959137      96.654614  0.006002
# ...           ...            ...            ...            ...       ...
# 33808         0.0       5.927978       9.899967      81.632945  0.148298
# 11758         0.0       5.430640       6.375402      75.262506  0.055608
# 24597         0.0       7.540412       6.785407      38.953862  0.325500
# 61494         0.0       2.421575       2.298815      45.962485  0.239154
# 27017         0.0       5.843692      14.674415      93.786038  0.153568
#
#        pvar  lrate  lratep  decay_rate  skipt1  ...     mse-l  testacc-m  \
# 2757    0.0    1.0     1.0         1.0     1.0  ...  0.012133   0.627703
# 36139   0.0    1.0     1.0         1.0     1.0  ...  0.016513   0.645780
# 25531   0.0    1.0     1.0         1.0     1.0  ...  0.013994   0.634598
# 47373   0.0    1.0     1.0         1.0     1.0  ...  0.013928   0.658537
# 28689   0.0    1.0     1.0         1.0     1.0  ...  0.020877   0.672674
# ...     ...    ...     ...         ...     ...  ...       ...        ...
# 33808   0.0    1.0     1.0         1.0     1.0  ...  0.071580   0.479119
# 11758   0.0    1.0     1.0         1.0     1.0  ...  0.071942   0.508810
# 24597   0.0    1.0     1.0         1.0     1.0  ...  0.070187   0.517752
# 61494   0.0    1.0     1.0         1.0     1.0  ...  0.087367   0.499513
# 27017   0.0    1.0     1.0         1.0     1.0  ...  0.071880   0.526562
#
#          acc2-m     mse-m  b-test_diff  i-test_diff  e-test_diff  m-test_diff  \
# 2757   0.526488  0.016366     0.068261     0.011119     0.073542     0.062634
# 36139  0.549706  0.013709     0.068510     0.004612     0.073788     0.044557
# 25531  0.556642  0.012629     0.068589     0.004931     0.073866     0.055739
# 47373  0.599187  0.009871     0.067887     0.022243     0.073162     0.031800
# 28689  0.760270  0.018320     0.068585     0.006639     0.073863     0.017663
# ...         ...       ...          ...          ...          ...          ...
# 33808  0.583791  0.054399     0.068128     0.140941     0.073407     0.211218
# 11758  0.613804  0.048294     0.068426     0.144068     0.073703     0.181527
# 24597  0.640267  0.049495     0.067546     0.148083     0.072822     0.172586
# 61494  0.736456  0.067268     0.045421     0.141565     0.031662     0.190824
# 27017  0.586086  0.038993     0.068108     0.138386     0.073390     0.163775
#
#        l-test_diff    mse-bi
# 2757      0.064647  0.023346
# 36139     0.085910  0.021789
# 25531     0.086245  0.021340
# 47373     0.089088  0.016559
# 28689     0.092153  0.017567
# ...            ...       ...
# 33808     0.265777  0.025878
# 11758     0.266717  0.027289
# 24597     0.267546  0.028218
# 61494     0.269264  0.031983
# 27017     0.272980  0.032818
#
# [9868 rows x 31 columns]

# %% [markdown]
# ### plt single condition

# %%
def get_cond_df(row):
  ## form query string for above row
  query_str = " and ".join(
    ["%s == %f"%(k,v) for k,v in dict(row.astype(float)[1:10].round(4)).items()]
  )
  print('query',query_str)
  ## df of single parameter condition`
  cond_df = datadf1.round(4).query(query_str)
  if not len(cond_df):
    cond_df = datadf2.round(4).query(query_str)
  paramstr = "__".join(["%s-%s"%(k,v) for k,v in cond_df.iloc[0][1:12].items()])
  print('found',paramstr)
  return cond_df

# %%
def plt_cond_df(cond_df):
  f,axar = plt.subplots(1,1,figsize=(20,8))
  ax=axar
  paramstr = "__".join(["%s-%s"%(k,v) for k,v in cond_df.iloc[0][1:12].items()])
  for c,cdf in cond_df.groupby('cond'):
    try:
#       if c not in ['blocked','interleaved']:
#         print('FIGURES WITH BI ONLY')
#         continue
      ax.plot(np.arange(200),cdf.acc,label=c)
    except:
      print('err',paramstr,c)
      continue
  ax.set_ylim(0,1)
  plt.legend()
  plt.axhline(0.5,c='k',ls='--')
  
  plt.title("%s\n%s"%(paramstr[:94],paramstr[94:]))
  plt.savefig('figures/analysis_gs/acc-%s.png'%paramstr)

# %%
## select single param for plotting full acc trace
row = sgsdf.sort_values('testacc-l',ascending=False).iloc[0]
# print(row.astype(float))
cond_df = get_cond_df(row)
# Out:
# query concentration == 3.365300 and stickiness_wi == 2.319300 and stickiness_bt == 21.830200 and sparsity == 0.105400 and pvar == 0.000000 and lrate == 1.000000 and lratep == 1.000000 and decay_rate == 1.000000 and skipt1 == 1.000000
# found concentration-3.3653__stickiness_wi-2.3193__stickiness_bt-21.8302__sparsity-0.1054__pvar-0__lrate-1__lratep-1.0__decay_rate-1.0__beta2-False__skipt1-True__ppd_allsch-False

# %%
## TOP PARAM BY MSE
row = gsdf.sort_values('mse-bi').iloc[0]
print(row.astype(float))
cond_df = get_cond_df(row)
plt_cond_df(cond_df)
# plt.savefig('figures/gs0125-topMSE')
# Out:
# Unnamed: 0        0.000000
# concentration     7.557978
# stickiness_wi     6.102942
# stickiness_bt    12.222393
# sparsity          0.043879
# pvar              0.000000
# lrate             1.000000
# lratep            1.000000
# decay_rate        1.000000
# skipt1            1.000000
# testacc-b         0.981872
# acc2-b            0.950757
# mse-b             0.006427
# testacc-e         0.981872
# acc2-e            0.950759
# mse-e             0.011780
# testacc-i         0.630122
# acc2-i            0.615654
# mse-i             0.004128
# testacc-l         0.628043
# acc2-l            0.609634
# mse-l             0.016452
# testacc-m         0.633128
# acc2-m            0.585445
# mse-m             0.010820
# b-test_diff       0.068463
# i-test_diff       0.019066
# e-test_diff       0.073740
# m-test_diff       0.057209
# l-test_diff       0.114731
# mse-bi            0.010555
# Name: 39330, dtype: float64
# query concentration == 7.558000 and stickiness_wi == 6.102900 and stickiness_bt == 12.222400 and sparsity == 0.043900 and pvar == 0.000000 and lrate == 1.000000 and lratep == 1.000000 and decay_rate == 1.000000 and skipt1 == 1.000000
# found concentration-7.558__stickiness_wi-6.1029__stickiness_bt-12.2224__sparsity-0.0439__pvar-0__lrate-1__lratep-1.0__decay_rate-1.0__beta2-False__skipt1-True__ppd_allsch-False

# %% [markdown]
# ### plot full subtable

# %%
for idx,row in sgsdf.iterrows():
  print()
  cond_df = get_cond_df(row)
  plt_cond_df(cond_df)
  plt.close('all')
# Out:
# query concentration == 4.004800 and stickiness_wi == 2.703000 and stickiness_bt == 18.601300 and sparsity == 0.028900 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.710700 and decay_rate == 0.991400 and skipt1 == 1.000000
# found concentration-4.0048__stickiness_wi-2.703__stickiness_bt-18.6013__sparsity-0.0289__pvar-0__lrate-1__lratep-0.7107__decay_rate-0.9914__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 4.398700 and stickiness_wi == 3.219000 and stickiness_bt == 31.890000 and sparsity == 0.024800 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.768400 and decay_rate == 0.994700 and skipt1 == 1.000000
# found concentration-4.3987__stickiness_wi-3.219__stickiness_bt-31.89__sparsity-0.0248__pvar-0__lrate-1__lratep-0.7684__decay_rate-0.9947__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 2.329400 and stickiness_wi == 1.245200 and stickiness_bt == 17.306300 and sparsity == 0.011500 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.673400 and decay_rate == 0.982600 and skipt1 == 1.000000
# found concentration-2.3294__stickiness_wi-1.2452__stickiness_bt-17.3063__sparsity-0.0115__pvar-0__lrate-1__lratep-0.6734__decay_rate-0.9826__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 2.768600 and stickiness_wi == 1.780200 and stickiness_bt == 75.115100 and sparsity == 0.015200 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.650300 and decay_rate == 0.981600 and skipt1 == 1.000000
# found concentration-2.7686__stickiness_wi-1.7802__stickiness_bt-75.1151__sparsity-0.0152__pvar-0__lrate-1__lratep-0.6503__decay_rate-0.9816__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 5.521300 and stickiness_wi == 4.581500 and stickiness_bt == 8.804000 and sparsity == 0.065700 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.915800 and decay_rate == 0.997100 and skipt1 == 1.000000
# found concentration-5.5213__stickiness_wi-4.5815__stickiness_bt-8.804__sparsity-0.0657__pvar-0__lrate-1__lratep-0.9158__decay_rate-0.9971__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 7.330000 and stickiness_wi == 33.086700 and stickiness_bt == 71.975800 and sparsity == 0.060400 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.808000 and decay_rate == 0.965100 and skipt1 == 1.000000
# found concentration-7.33__stickiness_wi-33.0867__stickiness_bt-71.9758__sparsity-0.0604__pvar-0__lrate-1__lratep-0.808__decay_rate-0.9651__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 1.363000 and stickiness_wi == 0.713200 and stickiness_bt == 20.936600 and sparsity == 0.040900 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.604200 and decay_rate == 0.996700 and skipt1 == 1.000000
# found concentration-1.363__stickiness_wi-0.7132__stickiness_bt-20.9366__sparsity-0.0409__pvar-0__lrate-1__lratep-0.6042__decay_rate-0.9967__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 5.315200 and stickiness_wi == 82.196400 and stickiness_bt == 59.090900 and sparsity == 0.047500 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.851900 and decay_rate == 0.982600 and skipt1 == 1.000000
# found concentration-5.3152__stickiness_wi-82.1964__stickiness_bt-59.0909__sparsity-0.0475__pvar-0__lrate-1__lratep-0.8519__decay_rate-0.9826__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 6.892600 and stickiness_wi == 51.490700 and stickiness_bt == 60.766300 and sparsity == 0.064200 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.918000 and decay_rate == 0.971800 and skipt1 == 1.000000
# found concentration-6.8926__stickiness_wi-51.4907__stickiness_bt-60.7663__sparsity-0.0642__pvar-0__lrate-1__lratep-0.918__decay_rate-0.9718__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 3.739600 and stickiness_wi == 54.841100 and stickiness_bt == 46.211300 and sparsity == 0.047500 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.722100 and decay_rate == 0.967800 and skipt1 == 1.000000
# found concentration-3.7396__stickiness_wi-54.8411__stickiness_bt-46.2113__sparsity-0.0475__pvar-0__lrate-1__lratep-0.7221__decay_rate-0.9678__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 4.136400 and stickiness_wi == 66.736000 and stickiness_bt == 94.865500 and sparsity == 0.041000 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.977100 and decay_rate == 0.975700 and skipt1 == 1.000000
# found concentration-4.1364__stickiness_wi-66.736__stickiness_bt-94.8655__sparsity-0.041__pvar-0__lrate-1__lratep-0.9771__decay_rate-0.9757__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 1.565000 and stickiness_wi == 58.322800 and stickiness_bt == 75.493400 and sparsity == 0.011200 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.560900 and decay_rate == 0.967100 and skipt1 == 1.000000
# found concentration-1.565__stickiness_wi-58.3228__stickiness_bt-75.4934__sparsity-0.0112__pvar-0__lrate-1__lratep-0.5609__decay_rate-0.9671__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 4.671000 and stickiness_wi == 40.140900 and stickiness_bt == 84.687500 and sparsity == 0.050700 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.957900 and decay_rate == 0.970200 and skipt1 == 1.000000
# found concentration-4.671__stickiness_wi-40.1409__stickiness_bt-84.6875__sparsity-0.0507__pvar-0__lrate-1__lratep-0.9579__decay_rate-0.9702__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 2.219500 and stickiness_wi == 74.154000 and stickiness_bt == 49.880400 and sparsity == 0.023000 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.421700 and decay_rate == 0.976900 and skipt1 == 1.000000
# found concentration-2.2195__stickiness_wi-74.154__stickiness_bt-49.8804__sparsity-0.023__pvar-0__lrate-1__lratep-0.4217__decay_rate-0.9769__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 3.142700 and stickiness_wi == 31.030900 and stickiness_bt == 51.950200 and sparsity == 0.059400 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.728300 and decay_rate == 0.970300 and skipt1 == 1.000000
# found concentration-3.1427__stickiness_wi-31.0309__stickiness_bt-51.9502__sparsity-0.0594__pvar-0__lrate-1__lratep-0.7283__decay_rate-0.9703__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 3.631500 and stickiness_wi == 22.506700 and stickiness_bt == 38.357000 and sparsity == 0.076800 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.655000 and decay_rate == 0.989400 and skipt1 == 1.000000
# found concentration-3.6315__stickiness_wi-22.5067__stickiness_bt-38.357__sparsity-0.0768__pvar-0__lrate-1__lratep-0.655__decay_rate-0.9894__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 2.615000 and stickiness_wi == 44.731200 and stickiness_bt == 62.490700 and sparsity == 0.034700 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.622300 and decay_rate == 0.983100 and skipt1 == 1.000000
# found concentration-2.615__stickiness_wi-44.7312__stickiness_bt-62.4907__sparsity-0.0347__pvar-0__lrate-1__lratep-0.6223__decay_rate-0.9831__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 4.203000 and stickiness_wi == 2.867000 and stickiness_bt == 76.018000 and sparsity == 0.090200 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.850500 and decay_rate == 0.991100 and skipt1 == 1.000000
# found concentration-4.203__stickiness_wi-2.867__stickiness_bt-76.018__sparsity-0.0902__pvar-0__lrate-1__lratep-0.8505__decay_rate-0.9911__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 4.404800 and stickiness_wi == 60.032500 and stickiness_bt == 74.576300 and sparsity == 0.044600 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.951700 and decay_rate == 0.966100 and skipt1 == 1.000000
# found concentration-4.4048__stickiness_wi-60.0325__stickiness_bt-74.5763__sparsity-0.0446__pvar-0__lrate-1__lratep-0.9517__decay_rate-0.9661__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 3.232400 and stickiness_wi == 54.033700 and stickiness_bt == 65.508900 and sparsity == 0.050500 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.637500 and decay_rate == 0.993800 and skipt1 == 1.000000
# found concentration-3.2324__stickiness_wi-54.0337__stickiness_bt-65.5089__sparsity-0.0505__pvar-0__lrate-1__lratep-0.6375__decay_rate-0.9938__beta2-False__skipt1-True__ppd_allsch-False
# query concentration == 1.057200 and stickiness_wi == 64.226100 and stickiness_bt == 87.882900 and sparsity == 0.012500 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.808400 and decay_rate == 0.999000 and skipt1 == 1.000000
# found concentration-1.0572__stickiness_wi-64.2261__stickiness_bt-87.8829__sparsity-0.0125__pvar-0__lrate-1__lratep-0.8084__decay_rate-0.999__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 2.867000 and stickiness_wi == 69.675700 and stickiness_bt == 86.739500 and sparsity == 0.033400 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.979100 and decay_rate == 0.995700 and skipt1 == 1.000000
# found concentration-2.867__stickiness_wi-69.6757__stickiness_bt-86.7395__sparsity-0.0334__pvar-0__lrate-1__lratep-0.9791__decay_rate-0.9957__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 3.415000 and stickiness_wi == 68.913500 and stickiness_bt == 62.491700 and sparsity == 0.040500 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.941500 and decay_rate == 0.997200 and skipt1 == 1.000000
# found concentration-3.415__stickiness_wi-68.9135__stickiness_bt-62.4917__sparsity-0.0405__pvar-0__lrate-1__lratep-0.9415__decay_rate-0.9972__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 1.178600 and stickiness_wi == 44.776200 and stickiness_bt == 80.660300 and sparsity == 0.019500 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.578600 and decay_rate == 0.980100 and skipt1 == 1.000000
# found concentration-1.1786__stickiness_wi-44.7762__stickiness_bt-80.6603__sparsity-0.0195__pvar-0__lrate-1__lratep-0.5786__decay_rate-0.9801__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 1.869700 and stickiness_wi == 77.297900 and stickiness_bt == 72.452600 and sparsity == 0.017500 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.584200 and decay_rate == 0.980900 and skipt1 == 1.000000
# found concentration-1.8697__stickiness_wi-77.2979__stickiness_bt-72.4526__sparsity-0.0175__pvar-0__lrate-1__lratep-0.5842__decay_rate-0.9809__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 1.474900 and stickiness_wi == 58.165800 and stickiness_bt == 48.161400 and sparsity == 0.016700 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.502100 and decay_rate == 0.969400 and skipt1 == 1.000000
# found concentration-1.4749__stickiness_wi-58.1658__stickiness_bt-48.1614__sparsity-0.0167__pvar-0__lrate-1__lratep-0.5021__decay_rate-0.9694__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 4.121600 and stickiness_wi == 32.297600 and stickiness_bt == 62.019200 and sparsity == 0.068400 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.967000 and decay_rate == 0.977700 and skipt1 == 1.000000
# found concentration-4.1216__stickiness_wi-32.2976__stickiness_bt-62.0192__sparsity-0.0684__pvar-0__lrate-1__lratep-0.967__decay_rate-0.9777__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 1.629500 and stickiness_wi == 74.212300 and stickiness_bt == 57.546000 and sparsity == 0.013500 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.759700 and decay_rate == 0.976100 and skipt1 == 1.000000
# found concentration-1.6295__stickiness_wi-74.2123__stickiness_bt-57.546__sparsity-0.0135__pvar-0__lrate-1__lratep-0.7597__decay_rate-0.9761__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 0.620400 and stickiness_wi == 51.438900 and stickiness_bt == 47.373300 and sparsity == 0.009000 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.226300 and decay_rate == 0.976800 and skipt1 == 1.000000
# found concentration-0.6204__stickiness_wi-51.4389__stickiness_bt-47.3733__sparsity-0.009__pvar-0__lrate-1__lratep-0.2263__decay_rate-0.9768__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 2.160000 and stickiness_wi == 51.683600 and stickiness_bt == 83.819700 and sparsity == 0.026700 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.547000 and decay_rate == 0.995200 and skipt1 == 1.000000
# found concentration-2.16__stickiness_wi-51.6836__stickiness_bt-83.8197__sparsity-0.0267__pvar-0__lrate-1__lratep-0.547__decay_rate-0.9952__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 1.095300 and stickiness_wi == 34.414900 and stickiness_bt == 57.509100 and sparsity == 0.021100 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.949900 and decay_rate == 0.986000 and skipt1 == 1.000000
# found concentration-1.0953__stickiness_wi-34.4149__stickiness_bt-57.5091__sparsity-0.0211__pvar-0__lrate-1__lratep-0.9499__decay_rate-0.986__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 1.533600 and stickiness_wi == 43.314600 and stickiness_bt == 56.595500 and sparsity == 0.027400 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.361100 and decay_rate == 0.995700 and skipt1 == 1.000000
# found concentration-1.5336__stickiness_wi-43.3146__stickiness_bt-56.5955__sparsity-0.0274__pvar-0__lrate-1__lratep-0.3611__decay_rate-0.9957__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 6.078700 and stickiness_wi == 80.386300 and stickiness_bt == 91.052100 and sparsity == 0.057700 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.962200 and decay_rate == 0.985400 and skipt1 == 1.000000
# found concentration-6.0787__stickiness_wi-80.3863__stickiness_bt-91.0521__sparsity-0.0577__pvar-0__lrate-1__lratep-0.9622__decay_rate-0.9854__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 3.606900 and stickiness_wi == 82.792000 and stickiness_bt == 75.486900 and sparsity == 0.029700 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.708900 and decay_rate == 0.971500 and skipt1 == 1.000000
# found concentration-3.6069__stickiness_wi-82.792__stickiness_bt-75.4869__sparsity-0.0297__pvar-0__lrate-1__lratep-0.7089__decay_rate-0.9715__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 3.786200 and stickiness_wi == 55.591300 and stickiness_bt == 83.700800 and sparsity == 0.050100 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.863500 and decay_rate == 0.992800 and skipt1 == 1.000000
# found concentration-3.7862__stickiness_wi-55.5913__stickiness_bt-83.7008__sparsity-0.0501__pvar-0__lrate-1__lratep-0.8635__decay_rate-0.9928__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 5.532100 and stickiness_wi == 39.997200 and stickiness_bt == 58.307100 and sparsity == 0.065800 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.872700 and decay_rate == 0.968900 and skipt1 == 1.000000
# found concentration-5.5321__stickiness_wi-39.9972__stickiness_bt-58.3071__sparsity-0.0658__pvar-0__lrate-1__lratep-0.8727__decay_rate-0.9689__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 2.123600 and stickiness_wi == 73.989900 and stickiness_bt == 99.520200 and sparsity == 0.024000 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.611300 and decay_rate == 0.986800 and skipt1 == 1.000000
# found concentration-2.1236__stickiness_wi-73.9899__stickiness_bt-99.5202__sparsity-0.024__pvar-0__lrate-1__lratep-0.6113__decay_rate-0.9868__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 6.120800 and stickiness_wi == 36.576300 and stickiness_bt == 46.699700 and sparsity == 0.101200 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.940400 and decay_rate == 0.999200 and skipt1 == 1.000000
# found concentration-6.1208__stickiness_wi-36.5763__stickiness_bt-46.6997__sparsity-0.1012__pvar-0__lrate-1__lratep-0.9404__decay_rate-0.9992__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 1.142200 and stickiness_wi == 57.809800 and stickiness_bt == 68.916900 and sparsity == 0.011700 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.851200 and decay_rate == 0.974600 and skipt1 == 1.000000
# found concentration-1.1422__stickiness_wi-57.8098__stickiness_bt-68.9169__sparsity-0.0117__pvar-0__lrate-1__lratep-0.8512__decay_rate-0.9746__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 3.164900 and stickiness_wi == 46.547300 and stickiness_bt == 52.581600 and sparsity == 0.035600 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.590300 and decay_rate == 0.971500 and skipt1 == 1.000000
# found concentration-3.1649__stickiness_wi-46.5473__stickiness_bt-52.5816__sparsity-0.0356__pvar-0__lrate-1__lratep-0.5903__decay_rate-0.9715__beta2-False__skipt1-True__ppd_allsch-False
# query concentration == 3.484300 and stickiness_wi == 35.596100 and stickiness_bt == 35.062600 and sparsity == 0.058400 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.873300 and decay_rate == 0.983400 and skipt1 == 1.000000
# found concentration-3.4843__stickiness_wi-35.5961__stickiness_bt-35.0626__sparsity-0.0584__pvar-0__lrate-1__lratep-0.8733__decay_rate-0.9834__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 1.763800 and stickiness_wi == 79.462400 and stickiness_bt == 62.088000 and sparsity == 0.018800 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.259200 and decay_rate == 0.982200 and skipt1 == 1.000000
# found concentration-1.7638__stickiness_wi-79.4624__stickiness_bt-62.088__sparsity-0.0188__pvar-0__lrate-1__lratep-0.2592__decay_rate-0.9822__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 1.774600 and stickiness_wi == 67.249900 and stickiness_bt == 57.101000 and sparsity == 0.019300 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.311800 and decay_rate == 0.966300 and skipt1 == 1.000000
# found concentration-1.7746__stickiness_wi-67.2499__stickiness_bt-57.101__sparsity-0.0193__pvar-0__lrate-1__lratep-0.3118__decay_rate-0.9663__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 2.158000 and stickiness_wi == 57.302600 and stickiness_bt == 59.158300 and sparsity == 0.023000 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.790600 and decay_rate == 0.976300 and skipt1 == 1.000000
# found concentration-2.158__stickiness_wi-57.3026__stickiness_bt-59.1583__sparsity-0.023__pvar-0__lrate-1__lratep-0.7906__decay_rate-0.9763__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 5.354200 and stickiness_wi == 62.016600 and stickiness_bt == 85.890600 and sparsity == 0.048200 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.894000 and decay_rate == 0.973400 and skipt1 == 1.000000
# found concentration-5.3542__stickiness_wi-62.0166__stickiness_bt-85.8906__sparsity-0.0482__pvar-0__lrate-1__lratep-0.894__decay_rate-0.9734__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 1.736200 and stickiness_wi == 39.377500 and stickiness_bt == 52.943800 and sparsity == 0.025800 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.834000 and decay_rate == 0.972900 and skipt1 == 1.000000
# found concentration-1.7362__stickiness_wi-39.3775__stickiness_bt-52.9438__sparsity-0.0258__pvar-0__lrate-1__lratep-0.834__decay_rate-0.9729__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 3.062100 and stickiness_wi == 2.191200 and stickiness_bt == 29.021900 and sparsity == 0.202200 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.615600 and decay_rate == 0.998000 and skipt1 == 1.000000
# found concentration-3.0621__stickiness_wi-2.1912__stickiness_bt-29.0219__sparsity-0.2022__pvar-0__lrate-1__lratep-0.6156__decay_rate-0.998__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 0.704700 and stickiness_wi == 41.371900 and stickiness_bt == 42.309200 and sparsity == 0.012900 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.154800 and decay_rate == 0.985400 and skipt1 == 1.000000
# found concentration-0.7047__stickiness_wi-41.3719__stickiness_bt-42.3092__sparsity-0.0129__pvar-0__lrate-1__lratep-0.1548__decay_rate-0.9854__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 0.711300 and stickiness_wi == 40.044700 and stickiness_bt == 58.525500 and sparsity == 0.009000 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.430100 and decay_rate == 0.993900 and skipt1 == 1.000000
# found concentration-0.7113__stickiness_wi-40.0447__stickiness_bt-58.5255__sparsity-0.009__pvar-0__lrate-1__lratep-0.4301__decay_rate-0.9939__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 5.353200 and stickiness_wi == 30.370900 and stickiness_bt == 50.318200 and sparsity == 0.080800 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.734400 and decay_rate == 0.981800 and skipt1 == 1.000000
# found concentration-5.3532__stickiness_wi-30.3709__stickiness_bt-50.3182__sparsity-0.0808__pvar-0__lrate-1__lratep-0.7344__decay_rate-0.9818__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 2.976100 and stickiness_wi == 77.277100 and stickiness_bt == 82.242900 and sparsity == 0.018000 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.794400 and decay_rate == 0.987300 and skipt1 == 1.000000
# found concentration-2.9761__stickiness_wi-77.2771__stickiness_bt-82.2429__sparsity-0.018__pvar-0__lrate-1__lratep-0.7944__decay_rate-0.9873__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 3.820100 and stickiness_wi == 36.017900 and stickiness_bt == 68.293700 and sparsity == 0.048000 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.785200 and decay_rate == 0.977600 and skipt1 == 1.000000
# found concentration-3.8201__stickiness_wi-36.0179__stickiness_bt-68.2937__sparsity-0.048__pvar-0__lrate-1__lratep-0.7852__decay_rate-0.9776__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 3.695100 and stickiness_wi == 60.198300 and stickiness_bt == 84.668400 and sparsity == 0.033300 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.852600 and decay_rate == 0.980000 and skipt1 == 1.000000
# found concentration-3.6951__stickiness_wi-60.1983__stickiness_bt-84.6684__sparsity-0.0333__pvar-0__lrate-1__lratep-0.8526__decay_rate-0.98__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 0.988200 and stickiness_wi == 57.377000 and stickiness_bt == 95.781400 and sparsity == 0.009900 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.723800 and decay_rate == 0.984600 and skipt1 == 1.000000
# found concentration-0.9882__stickiness_wi-57.377__stickiness_bt-95.7814__sparsity-0.0099__pvar-0__lrate-1__lratep-0.7238__decay_rate-0.9846__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 2.707500 and stickiness_wi == 61.531900 and stickiness_bt == 65.036500 and sparsity == 0.028000 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.770700 and decay_rate == 0.988000 and skipt1 == 1.000000
# found concentration-2.7075__stickiness_wi-61.5319__stickiness_bt-65.0365__sparsity-0.028__pvar-0__lrate-1__lratep-0.7707__decay_rate-0.988__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 0.562000 and stickiness_wi == 26.654700 and stickiness_bt == 37.732800 and sparsity == 0.011900 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.102800 and decay_rate == 0.992200 and skipt1 == 1.000000
# found concentration-0.562__stickiness_wi-26.6547__stickiness_bt-37.7328__sparsity-0.0119__pvar-0__lrate-1__lratep-0.1028__decay_rate-0.9922__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 2.472600 and stickiness_wi == 67.242800 and stickiness_bt == 99.778700 and sparsity == 0.022900 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.827900 and decay_rate == 0.979500 and skipt1 == 1.000000
# found concentration-2.4726__stickiness_wi-67.2428__stickiness_bt-99.7787__sparsity-0.0229__pvar-0__lrate-1__lratep-0.8279__decay_rate-0.9795__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 2.223200 and stickiness_wi == 97.668400 and stickiness_bt == 96.269000 and sparsity == 0.018200 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.554900 and decay_rate == 0.967200 and skipt1 == 1.000000
# found concentration-2.2232__stickiness_wi-97.6684__stickiness_bt-96.269__sparsity-0.0182__pvar-0__lrate-1__lratep-0.5549__decay_rate-0.9672__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 5.886700 and stickiness_wi == 32.944400 and stickiness_bt == 45.175600 and sparsity == 0.129200 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.955700 and decay_rate == 0.995100 and skipt1 == 1.000000
# found concentration-5.8867__stickiness_wi-32.9444__stickiness_bt-45.1756__sparsity-0.1292__pvar-0__lrate-1__lratep-0.9557__decay_rate-0.9951__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 4.140000 and stickiness_wi == 53.973700 and stickiness_bt == 54.576500 and sparsity == 0.057600 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.717600 and decay_rate == 0.984300 and skipt1 == 1.000000
# found concentration-4.14__stickiness_wi-53.9737__stickiness_bt-54.5765__sparsity-0.0576__pvar-0__lrate-1__lratep-0.7176__decay_rate-0.9843__beta2-False__skipt1-True__ppd_allsch-False
# query concentration == 1.217500 and stickiness_wi == 14.608800 and stickiness_bt == 48.755600 and sparsity == 0.032900 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.662700 and decay_rate == 0.986900 and skipt1 == 1.000000
# found concentration-1.2175__stickiness_wi-14.6088__stickiness_bt-48.7556__sparsity-0.0329__pvar-0__lrate-1__lratep-0.6627__decay_rate-0.9869__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 3.226400 and stickiness_wi == 28.865300 and stickiness_bt == 83.144600 and sparsity == 0.044900 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.723800 and decay_rate == 0.965800 and skipt1 == 1.000000
# found concentration-3.2264__stickiness_wi-28.8653__stickiness_bt-83.1446__sparsity-0.0449__pvar-0__lrate-1__lratep-0.7238__decay_rate-0.9658__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 2.277300 and stickiness_wi == 30.391500 and stickiness_bt == 57.178900 and sparsity == 0.040400 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.692400 and decay_rate == 0.965600 and skipt1 == 1.000000
# found concentration-2.2773__stickiness_wi-30.3915__stickiness_bt-57.1789__sparsity-0.0404__pvar-0__lrate-1__lratep-0.6924__decay_rate-0.9656__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 3.373900 and stickiness_wi == 21.246400 and stickiness_bt == 55.601700 and sparsity == 0.077000 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.893900 and decay_rate == 0.976100 and skipt1 == 1.000000
# found concentration-3.3739__stickiness_wi-21.2464__stickiness_bt-55.6017__sparsity-0.077__pvar-0__lrate-1__lratep-0.8939__decay_rate-0.9761__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 1.211300 and stickiness_wi == 1.785100 and stickiness_bt == 90.322400 and sparsity == 0.021200 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.984900 and decay_rate == 0.981500 and skipt1 == 1.000000
# found concentration-1.2113__stickiness_wi-1.7851__stickiness_bt-90.3224__sparsity-0.0212__pvar-0__lrate-1__lratep-0.9849__decay_rate-0.9815__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 1.408000 and stickiness_wi == 38.954700 and stickiness_bt == 58.825200 and sparsity == 0.028800 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.345000 and decay_rate == 0.997200 and skipt1 == 1.000000
# found concentration-1.408__stickiness_wi-38.9547__stickiness_bt-58.8252__sparsity-0.0288__pvar-0__lrate-1__lratep-0.345__decay_rate-0.9972__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 4.188600 and stickiness_wi == 91.982000 and stickiness_bt == 78.417900 and sparsity == 0.035100 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.851500 and decay_rate == 0.967100 and skipt1 == 1.000000
# found concentration-4.1886__stickiness_wi-91.982__stickiness_bt-78.4179__sparsity-0.0351__pvar-0__lrate-1__lratep-0.8515__decay_rate-0.9671__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 2.761000 and stickiness_wi == 59.062300 and stickiness_bt == 49.900800 and sparsity == 0.035000 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.518400 and decay_rate == 0.973400 and skipt1 == 1.000000
# found concentration-2.761__stickiness_wi-59.0623__stickiness_bt-49.9008__sparsity-0.035__pvar-0__lrate-1__lratep-0.5184__decay_rate-0.9734__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 2.549800 and stickiness_wi == 23.439300 and stickiness_bt == 63.285200 and sparsity == 0.071500 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.679900 and decay_rate == 0.996700 and skipt1 == 1.000000
# found concentration-2.5498__stickiness_wi-23.4393__stickiness_bt-63.2852__sparsity-0.0715__pvar-0__lrate-1__lratep-0.6799__decay_rate-0.9967__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 1.869100 and stickiness_wi == 18.314400 and stickiness_bt == 13.881300 and sparsity == 0.065400 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.731900 and decay_rate == 0.995500 and skipt1 == 1.000000
# found concentration-1.8691__stickiness_wi-18.3144__stickiness_bt-13.8813__sparsity-0.0654__pvar-0__lrate-1__lratep-0.7319__decay_rate-0.9955__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 0.845600 and stickiness_wi == 17.360600 and stickiness_bt == 40.506500 and sparsity == 0.017500 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.922600 and decay_rate == 0.971000 and skipt1 == 1.000000
# found concentration-0.8456__stickiness_wi-17.3606__stickiness_bt-40.5065__sparsity-0.0175__pvar-0__lrate-1__lratep-0.9226__decay_rate-0.971__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 1.114700 and stickiness_wi == 34.999800 and stickiness_bt == 93.128100 and sparsity == 0.018000 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.584600 and decay_rate == 0.996900 and skipt1 == 1.000000
# found concentration-1.1147__stickiness_wi-34.9998__stickiness_bt-93.1281__sparsity-0.018__pvar-0__lrate-1__lratep-0.5846__decay_rate-0.9969__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 3.208100 and stickiness_wi == 55.843000 and stickiness_bt == 70.911300 and sparsity == 0.029400 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.836400 and decay_rate == 0.972500 and skipt1 == 1.000000
# found concentration-3.2081__stickiness_wi-55.843__stickiness_bt-70.9113__sparsity-0.0294__pvar-0__lrate-1__lratep-0.8364__decay_rate-0.9725__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 2.929700 and stickiness_wi == 34.246900 and stickiness_bt == 84.844200 and sparsity == 0.041400 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.694900 and decay_rate == 0.981500 and skipt1 == 1.000000
# found concentration-2.9297__stickiness_wi-34.2469__stickiness_bt-84.8442__sparsity-0.0414__pvar-0__lrate-1__lratep-0.6949__decay_rate-0.9815__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 5.924600 and stickiness_wi == 50.993400 and stickiness_bt == 72.397200 and sparsity == 0.057800 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.949700 and decay_rate == 0.968000 and skipt1 == 1.000000
# found concentration-5.9246__stickiness_wi-50.9934__stickiness_bt-72.3972__sparsity-0.0578__pvar-0__lrate-1__lratep-0.9497__decay_rate-0.968__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 3.399000 and stickiness_wi == 90.379300 and stickiness_bt == 98.626900 and sparsity == 0.023000 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.912000 and decay_rate == 0.975500 and skipt1 == 1.000000
# found concentration-3.399__stickiness_wi-90.3793__stickiness_bt-98.6269__sparsity-0.023__pvar-0__lrate-1__lratep-0.912__decay_rate-0.9755__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 1.632300 and stickiness_wi == 60.172300 and stickiness_bt == 44.987900 and sparsity == 0.019400 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.785200 and decay_rate == 0.988300 and skipt1 == 1.000000
# found concentration-1.6323__stickiness_wi-60.1723__stickiness_bt-44.9879__sparsity-0.0194__pvar-0__lrate-1__lratep-0.7852__decay_rate-0.9883__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 2.115100 and stickiness_wi == 62.937000 and stickiness_bt == 82.847500 and sparsity == 0.023500 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.564800 and decay_rate == 0.987800 and skipt1 == 1.000000
# found concentration-2.1151__stickiness_wi-62.937__stickiness_bt-82.8475__sparsity-0.0235__pvar-0__lrate-1__lratep-0.5648__decay_rate-0.9878__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 4.173700 and stickiness_wi == 15.446000 and stickiness_bt == 28.866800 and sparsity == 0.113200 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.822300 and decay_rate == 0.994100 and skipt1 == 1.000000
# found concentration-4.1737__stickiness_wi-15.446__stickiness_bt-28.8668__sparsity-0.1132__pvar-0__lrate-1__lratep-0.8223__decay_rate-0.9941__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 2.997300 and stickiness_wi == 25.848800 and stickiness_bt == 35.969100 and sparsity == 0.043900 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.712300 and decay_rate == 0.970300 and skipt1 == 1.000000
# found concentration-2.9973__stickiness_wi-25.8488__stickiness_bt-35.9691__sparsity-0.0439__pvar-0__lrate-1__lratep-0.7123__decay_rate-0.9703__beta2-False__skipt1-True__ppd_allsch-False
# query concentration == 3.539600 and stickiness_wi == 21.951000 and stickiness_bt == 43.948100 and sparsity == 0.106800 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.760500 and decay_rate == 0.986600 and skipt1 == 1.000000
# found concentration-3.5396__stickiness_wi-21.951__stickiness_bt-43.9481__sparsity-0.1068__pvar-0__lrate-1__lratep-0.7605__decay_rate-0.9866__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 4.726700 and stickiness_wi == 23.562200 and stickiness_bt == 29.862000 and sparsity == 0.148300 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.699800 and decay_rate == 0.997600 and skipt1 == 1.000000
# found concentration-4.7267__stickiness_wi-23.5622__stickiness_bt-29.862__sparsity-0.1483__pvar-0__lrate-1__lratep-0.6998__decay_rate-0.9976__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 3.519000 and stickiness_wi == 0.761300 and stickiness_bt == 21.865900 and sparsity == 0.089800 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.955500 and decay_rate == 0.986800 and skipt1 == 1.000000
# found concentration-3.519__stickiness_wi-0.7613__stickiness_bt-21.8659__sparsity-0.0898__pvar-0__lrate-1__lratep-0.9555__decay_rate-0.9868__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 7.066600 and stickiness_wi == 5.336200 and stickiness_bt == 84.210200 and sparsity == 0.054700 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.963600 and decay_rate == 0.970800 and skipt1 == 1.000000
# found concentration-7.0666__stickiness_wi-5.3362__stickiness_bt-84.2102__sparsity-0.0547__pvar-0__lrate-1__lratep-0.9636__decay_rate-0.9708__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 1.487900 and stickiness_wi == 12.736600 and stickiness_bt == 80.537200 and sparsity == 0.039200 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.847400 and decay_rate == 0.970900 and skipt1 == 1.000000
# found concentration-1.4879__stickiness_wi-12.7366__stickiness_bt-80.5372__sparsity-0.0392__pvar-0__lrate-1__lratep-0.8474__decay_rate-0.9709__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 2.592300 and stickiness_wi == 66.380600 and stickiness_bt == 46.915500 and sparsity == 0.028800 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.740800 and decay_rate == 0.989600 and skipt1 == 1.000000
# found concentration-2.5923__stickiness_wi-66.3806__stickiness_bt-46.9155__sparsity-0.0288__pvar-0__lrate-1__lratep-0.7408__decay_rate-0.9896__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 2.621600 and stickiness_wi == 99.619900 and stickiness_bt == 81.812600 and sparsity == 0.018200 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.719600 and decay_rate == 0.985300 and skipt1 == 1.000000
# found concentration-2.6216__stickiness_wi-99.6199__stickiness_bt-81.8126__sparsity-0.0182__pvar-0__lrate-1__lratep-0.7196__decay_rate-0.9853__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 6.886500 and stickiness_wi == 71.601900 and stickiness_bt == 98.465800 and sparsity == 0.066700 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.936500 and decay_rate == 0.975800 and skipt1 == 1.000000
# found concentration-6.8865__stickiness_wi-71.6019__stickiness_bt-98.4658__sparsity-0.0667__pvar-0__lrate-1__lratep-0.9365__decay_rate-0.9758__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 5.077700 and stickiness_wi == 73.113800 and stickiness_bt == 81.890100 and sparsity == 0.061200 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.684500 and decay_rate == 0.995600 and skipt1 == 1.000000
# found concentration-5.0777__stickiness_wi-73.1138__stickiness_bt-81.8901__sparsity-0.0612__pvar-0__lrate-1__lratep-0.6845__decay_rate-0.9956__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 2.117100 and stickiness_wi == 98.815300 and stickiness_bt == 90.256800 and sparsity == 0.012000 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.752600 and decay_rate == 0.992900 and skipt1 == 1.000000
# found concentration-2.1171__stickiness_wi-98.8153__stickiness_bt-90.2568__sparsity-0.012__pvar-0__lrate-1__lratep-0.7526__decay_rate-0.9929__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 3.201900 and stickiness_wi == 20.729100 and stickiness_bt == 53.304700 and sparsity == 0.108300 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.602700 and decay_rate == 0.997300 and skipt1 == 1.000000
# found concentration-3.2019__stickiness_wi-20.7291__stickiness_bt-53.3047__sparsity-0.1083__pvar-0__lrate-1__lratep-0.6027__decay_rate-0.9973__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 4.121600 and stickiness_wi == 78.016100 and stickiness_bt == 64.949300 and sparsity == 0.040300 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.812300 and decay_rate == 0.987100 and skipt1 == 1.000000
# found concentration-4.1216__stickiness_wi-78.0161__stickiness_bt-64.9493__sparsity-0.0403__pvar-0__lrate-1__lratep-0.8123__decay_rate-0.9871__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 0.185300 and stickiness_wi == 19.953500 and stickiness_bt == 74.096100 and sparsity == 0.006100 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.636100 and decay_rate == 0.996800 and skipt1 == 1.000000
# found concentration-0.1853__stickiness_wi-19.9535__stickiness_bt-74.0961__sparsity-0.0061__pvar-0__lrate-1__lratep-0.6361__decay_rate-0.9968__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 3.752400 and stickiness_wi == 62.313200 and stickiness_bt == 53.519600 and sparsity == 0.040900 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.658300 and decay_rate == 0.967600 and skipt1 == 1.000000
# found concentration-3.7524__stickiness_wi-62.3132__stickiness_bt-53.5196__sparsity-0.0409__pvar-0__lrate-1__lratep-0.6583__decay_rate-0.9676__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 4.156000 and stickiness_wi == 35.494200 and stickiness_bt == 97.274000 and sparsity == 0.074000 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.984100 and decay_rate == 0.998300 and skipt1 == 1.000000
# found concentration-4.156__stickiness_wi-35.4942__stickiness_bt-97.274__sparsity-0.074__pvar-0__lrate-1__lratep-0.9841__decay_rate-0.9983__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 2.031500 and stickiness_wi == 24.478700 and stickiness_bt == 25.518900 and sparsity == 0.039500 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.879200 and decay_rate == 0.978500 and skipt1 == 1.000000
# found concentration-2.0315__stickiness_wi-24.4787__stickiness_bt-25.5189__sparsity-0.0395__pvar-0__lrate-1__lratep-0.8792__decay_rate-0.9785__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 3.745900 and stickiness_wi == 51.760300 and stickiness_bt == 53.925300 and sparsity == 0.036800 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.979900 and decay_rate == 0.971300 and skipt1 == 1.000000
# found concentration-3.7459__stickiness_wi-51.7603__stickiness_bt-53.9253__sparsity-0.0368__pvar-0__lrate-1__lratep-0.9799__decay_rate-0.9713__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 0.668100 and stickiness_wi == 14.382100 and stickiness_bt == 24.724500 and sparsity == 0.030000 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.343000 and decay_rate == 0.994300 and skipt1 == 1.000000
# found concentration-0.6681__stickiness_wi-14.3821__stickiness_bt-24.7245__sparsity-0.03__pvar-0__lrate-1__lratep-0.343__decay_rate-0.9943__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 2.830600 and stickiness_wi == 0.347000 and stickiness_bt == 32.732900 and sparsity == 0.052500 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.961500 and decay_rate == 0.997800 and skipt1 == 1.000000
# found concentration-2.8306__stickiness_wi-0.347__stickiness_bt-32.7329__sparsity-0.0525__pvar-0__lrate-1__lratep-0.9615__decay_rate-0.9978__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 3.197800 and stickiness_wi == 42.233400 and stickiness_bt == 86.628700 and sparsity == 0.053300 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.620900 and decay_rate == 0.971500 and skipt1 == 1.000000
# found concentration-3.1978__stickiness_wi-42.2334__stickiness_bt-86.6287__sparsity-0.0533__pvar-0__lrate-1__lratep-0.6209__decay_rate-0.9715__beta2-False__skipt1-True__ppd_allsch-False
# query concentration == 1.704000 and stickiness_wi == 1.664000 and stickiness_bt == 22.364400 and sparsity == 0.154400 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.758500 and decay_rate == 0.996500 and skipt1 == 1.000000
# found concentration-1.704__stickiness_wi-1.664__stickiness_bt-22.3644__sparsity-0.1544__pvar-0__lrate-1__lratep-0.7585__decay_rate-0.9965__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 4.990900 and stickiness_wi == 80.508700 and stickiness_bt == 89.610700 and sparsity == 0.045600 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.656100 and decay_rate == 0.970400 and skipt1 == 1.000000
# found concentration-4.9909__stickiness_wi-80.5087__stickiness_bt-89.6107__sparsity-0.0456__pvar-0__lrate-1__lratep-0.6561__decay_rate-0.9704__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 1.957000 and stickiness_wi == 81.757500 and stickiness_bt == 69.478200 and sparsity == 0.017000 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.583400 and decay_rate == 0.974800 and skipt1 == 1.000000
# found concentration-1.957__stickiness_wi-81.7575__stickiness_bt-69.4782__sparsity-0.017__pvar-0__lrate-1__lratep-0.5834__decay_rate-0.9748__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 5.514100 and stickiness_wi == 97.158000 and stickiness_bt == 97.879600 and sparsity == 0.042100 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.887000 and decay_rate == 0.980000 and skipt1 == 1.000000
# found concentration-5.5141__stickiness_wi-97.158__stickiness_bt-97.8796__sparsity-0.0421__pvar-0__lrate-1__lratep-0.887__decay_rate-0.98__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 4.642300 and stickiness_wi == 73.267400 and stickiness_bt == 70.341200 and sparsity == 0.051600 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.721300 and decay_rate == 0.983500 and skipt1 == 1.000000
# found concentration-4.6423__stickiness_wi-73.2674__stickiness_bt-70.3412__sparsity-0.0516__pvar-0__lrate-1__lratep-0.7213__decay_rate-0.9835__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 3.468500 and stickiness_wi == 33.272900 and stickiness_bt == 78.623000 and sparsity == 0.048500 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.925800 and decay_rate == 0.967400 and skipt1 == 1.000000
# found concentration-3.4685__stickiness_wi-33.2729__stickiness_bt-78.623__sparsity-0.0485__pvar-0__lrate-1__lratep-0.9258__decay_rate-0.9674__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 4.156500 and stickiness_wi == 13.311800 and stickiness_bt == 19.016100 and sparsity == 0.116200 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.777300 and decay_rate == 0.968600 and skipt1 == 1.000000
# found concentration-4.1565__stickiness_wi-13.3118__stickiness_bt-19.0161__sparsity-0.1162__pvar-0__lrate-1__lratep-0.7773__decay_rate-0.9686__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 4.787700 and stickiness_wi == 56.677400 and stickiness_bt == 66.340000 and sparsity == 0.040700 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.732200 and decay_rate == 0.993200 and skipt1 == 1.000000
# found concentration-4.7877__stickiness_wi-56.6774__stickiness_bt-66.34__sparsity-0.0407__pvar-0__lrate-1__lratep-0.7322__decay_rate-0.9932__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 2.120500 and stickiness_wi == 63.534200 and stickiness_bt == 73.148700 and sparsity == 0.020200 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.508300 and decay_rate == 0.982300 and skipt1 == 1.000000
# found concentration-2.1205__stickiness_wi-63.5342__stickiness_bt-73.1487__sparsity-0.0202__pvar-0__lrate-1__lratep-0.5083__decay_rate-0.9823__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 3.874300 and stickiness_wi == 25.679900 and stickiness_bt == 66.336400 and sparsity == 0.064700 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.930800 and decay_rate == 0.985000 and skipt1 == 1.000000
# found concentration-3.8743__stickiness_wi-25.6799__stickiness_bt-66.3364__sparsity-0.0647__pvar-0__lrate-1__lratep-0.9308__decay_rate-0.985__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 3.875700 and stickiness_wi == 29.332200 and stickiness_bt == 87.099300 and sparsity == 0.084000 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.797700 and decay_rate == 0.990000 and skipt1 == 1.000000
# found concentration-3.8757__stickiness_wi-29.3322__stickiness_bt-87.0993__sparsity-0.084__pvar-0__lrate-1__lratep-0.7977__decay_rate-0.99__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 4.149900 and stickiness_wi == 13.567700 and stickiness_bt == 43.349400 and sparsity == 0.132000 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.971800 and decay_rate == 0.999500 and skipt1 == 1.000000
# found concentration-4.1499__stickiness_wi-13.5677__stickiness_bt-43.3494__sparsity-0.132__pvar-0__lrate-1__lratep-0.9718__decay_rate-0.9995__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 3.858000 and stickiness_wi == 90.976500 and stickiness_bt == 80.408800 and sparsity == 0.026300 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.620500 and decay_rate == 0.974200 and skipt1 == 1.000000
# found concentration-3.858__stickiness_wi-90.9765__stickiness_bt-80.4088__sparsity-0.0263__pvar-0__lrate-1__lratep-0.6205__decay_rate-0.9742__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 0.964600 and stickiness_wi == 0.853600 and stickiness_bt == 46.573800 and sparsity == 0.043700 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.327800 and decay_rate == 0.973400 and skipt1 == 1.000000
# found concentration-0.9646__stickiness_wi-0.8536__stickiness_bt-46.5738__sparsity-0.0437__pvar-0__lrate-1__lratep-0.3278__decay_rate-0.9734__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 4.779400 and stickiness_wi == 21.383800 and stickiness_bt == 32.904300 and sparsity == 0.091000 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.882600 and decay_rate == 0.985700 and skipt1 == 1.000000
# found concentration-4.7794__stickiness_wi-21.3838__stickiness_bt-32.9043__sparsity-0.091__pvar-0__lrate-1__lratep-0.8826__decay_rate-0.9857__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 3.731000 and stickiness_wi == 35.522300 and stickiness_bt == 70.184500 and sparsity == 0.069000 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.991100 and decay_rate == 0.985100 and skipt1 == 1.000000
# found concentration-3.731__stickiness_wi-35.5223__stickiness_bt-70.1845__sparsity-0.069__pvar-0__lrate-1__lratep-0.9911__decay_rate-0.9851__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 6.347900 and stickiness_wi == 68.621700 and stickiness_bt == 54.751000 and sparsity == 0.065200 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.944700 and decay_rate == 0.965400 and skipt1 == 1.000000
# found concentration-6.3479__stickiness_wi-68.6217__stickiness_bt-54.751__sparsity-0.0652__pvar-0__lrate-1__lratep-0.9447__decay_rate-0.9654__beta2-False__skipt1-True__ppd_allsch-False
#
# query concentration == 3.769600 and stickiness_wi == 38.270300 and stickiness_bt == 70.933900 and sparsity == 0.042700 and pvar == 0.000000 and lrate == 1.000000 and lratep == 0.686700 and decay_rate == 0.975900 and skipt1 == 1.000000
# found concentration-3.7696__stickiness_wi-38.2703__stickiness_bt-70.9339__sparsity-0.0427__pvar-0__lrate-1__lratep-0.6867__decay_rate-0.9759__beta2-False__skipt1-True__ppd_allsch-False
