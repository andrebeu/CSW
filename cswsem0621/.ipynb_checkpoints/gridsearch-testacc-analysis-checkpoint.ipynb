# %% [markdown]
# # implement line sweeps of params
# - all params fixed expcet one, which is swept over range
# - specifically looking at test accuracy as a function of one param

# %%
from matplotlib import pyplot as plt
from scipy.special import softmax
from itertools import product

import numpy as np
from utils import *
from model import *
import time
import seaborn as sns
sns.set_context('talk')

# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from glob import glob as glob
gsdir = "data/gs0823/"
L = []
for fp in glob(gsdir+'*'):
  df_ = pd.read_csv(fp)
  L.append(df_)

# %%
gsdf.loc[:,'diff_mi'] = gsdf.middle - gsdf.interleaved

# %%
D10 = gsdf.diff_mi > 0.15
B50 = gsdf.blocked > 0.9
Ilow = gsdf.interleaved < 0.6
gsdf[D10&B50&Ilow].sort_values('middle',ascending=False)
# Out:
#     Unnamed: 0  concentration  stickiness_wi  stickiness_bt  sparsity  pvar  \
# 11          11           1.11         5000.0           10.0     0.035   2.0
# 25          25           2.51         5000.0            8.0     0.160   2.0
# 23          23           2.31         4000.0            8.0     0.160   2.0
# 6            6           0.61         4000.0            8.0     0.035   2.0
# 13          13           1.31         5000.0           10.0     0.060   2.0
# 15          15           1.51         5000.0            8.0     0.085   2.0
# 22          22           2.21         4000.0           10.0     0.085   2.0
#
#     lrate  lratep  decay_rate   blocked  interleaved     early    middle  \
# 11    0.8     1.0        0.99  0.909545     0.580743  0.944889  0.796803
# 25    1.0     0.8        1.00  1.000000     0.574250  1.000000  0.731500
# 23    1.0     0.8        1.00  0.988750     0.548250  1.000000  0.728750
# 6     1.0     0.8        1.00  0.942000     0.531750  0.968500  0.703250
# 13    1.0     1.0        1.00  0.966750     0.549000  0.956250  0.699000
# 15    1.0     0.8        0.99  1.000000     0.538671  1.000000  0.697629
# 22    0.8     1.0        0.99  1.000000     0.508086  0.967001  0.672983
#
#         late   diff_mi
# 11  0.785625  0.216060
# 25  0.687500  0.157250
# 23  0.706250  0.180500
# 6   0.601500  0.171500
# 13  0.596250  0.150000
# 15  0.707500  0.158959
# 22  0.561049  0.164897

# %%
BI = gsdf.blocked > gsdf.interleaved
BM = gsdf.blocked > gsdf.middle
MI = gsdf.middle > gsdf.interleaved
LI = gsdf.late > gsdf.interleaved
B50 = gsdf.blocked > 0.8
M50 = gsdf.middle > 0.7
I60 = gsdf.interleaved < 0.6
gsdf[BI&BM&MI&B50&LI&I60&M50].sort_values(['blocked','middle'],ascending=False)
# Out:
#     Unnamed: 0  concentration  stickiness_wi  stickiness_bt  sparsity  pvar  \
# 0            0           0.01         4000.0            8.0     0.035   2.0
# 1            1           0.11         4000.0            8.0     0.035   2.0
# 2            2           0.21         4000.0            8.0     0.035   2.0
# 3            3           0.31         4000.0            8.0     0.035   2.0
# 4            4           0.41         4000.0            8.0     0.035   2.0
# ..         ...            ...            ...            ...       ...   ...
# 23          23           2.31         4000.0           10.0     0.360   2.0
# 24          24           2.41         4000.0           10.0     0.360   2.0
# 25          25           2.51         4000.0           10.0     0.360   2.0
# 26          26           2.61         4000.0           10.0     0.360   2.0
# 27          27           2.71         4000.0           10.0     0.360   2.0
#
#     lrate  lratep  decay_rate   blocked  interleaved     early    middle  \
# 0     0.8     1.0        0.99  0.519499     0.487013  0.518686  0.501235
# 1     0.8     1.0        0.99  0.510527     0.491840  0.492478  0.515572
# 2     0.8     1.0        0.99  0.515708     0.493202  0.500499  0.488731
# 3     0.8     1.0        0.99  0.475109     0.498159  0.505173  0.509119
# 4     0.8     1.0        0.99  0.501244     0.505265  0.495084  0.487115
# ..    ...     ...         ...       ...          ...       ...       ...
# 23    1.0     0.9        0.99  0.484358     0.485210  0.511647  0.517518
# 24    1.0     0.9        0.99  0.497497     0.482311  0.476426  0.494289
# 25    1.0     0.9        0.99  0.507981     0.508126  0.488820  0.502697
# 26    1.0     0.9        0.99  0.513586     0.498191  0.500150  0.503396
# 27    1.0     0.9        0.99  0.490062     0.502853  0.503981  0.505586
#
#         late
# 0   0.501000
# 1   0.528524
# 2   0.478524
# 3   0.476842
# 4   0.508485
# ..       ...
# 23  0.508329
# 24  0.513560
# 25  0.481131
# 26  0.523918
# 27  0.512467
#
# [52388 rows x 14 columns]

# %%
assert False
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-99-a871fdc9ebee> in <module>
# ----> 1 assert False
#
# AssertionError:

# %%
## timestamp and dir for saving
tstamp = time.perf_counter_ns()
import os
os.mkdir('figures/scratch_folders/%i'%tstamp)

# %%
## default params
expargs = {
  'condition':'blocked',
  'n_train':160,
  'n_test':40
}
schargs = {
    'concentration':1.4,
    'stickiness_wi':5000,
    'stickiness_bt':5, # 100
    'sparsity':0.08,
    'pvar': 2,
    'lrate':0.8,
    'lratep':1,
    'decay_rate':1,
} 
args = {
    'sch':schargs,
    'exp':expargs
}
param_str = "-".join(["%s_%.3f"%(i,j) for i,j in schargs.items()])
param_str
# Out:
# 'concentration_1.400-stickiness_wi_5000.000-stickiness_bt_5.000-sparsity_0.080-pvar_2.000-lrate_0.800-lratep_1.000-decay_rate_1.000'

# %%
gridD = {
  'concentration': [1.4,2.0,2.2],
  'stickiness_wi': [5000],
  'stickiness_bt': [5,10],
  'sparsity': [0.08],
  'pvar': [2],
  'lrate': [1],
  'lratep': [1],
  'decay_rate': [0.99],
}

gridD
## grid
pnames = [i for i in gridD.keys()]
pranges = [i for i in gridD.values()]
for idx,i in enumerate(product(*pranges)):
  d = dict(zip(pnames,i))
  
print('number of param conditions',idx)
print(d)
# Out:
# number of param conditions 5
# {'concentration': 2.2, 'stickiness_wi': 5000, 'stickiness_bt': 10, 'sparsity': 0.08, 'pvar': 2, 'lrate': 1, 'lratep': 1, 'decay_rate': 0.99}

# %%
i,pnames
# dict(zip(pnames,i))

pvalstr = " ".join([str(j) for j in i])
out = "%s+%s"%(pnames,pvalstr)
out.split('+')[0]
pval
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-0bfa2eff192e> in <module>
#       5 out = "%s+%s"%(pnames,pvalstr)
#       6 out.split('+')[0]
# ----> 7 pvals
#
# NameError: name 'pvals' is not defined

# %% [markdown]
# ### main

# %%
def pltsave_macc(macc,schargs=None,labL=['B','I','E','M','L'],close=True):
  """ 
  save accuracy of individual parameter setting 
  used in paramsearch loops
  """
  plt.figure(figsize=(10,4))
  ax=plt.gca()
  for idx in range(len(macc)):
    ax.plot(macc[idx],label=labL[idx])
  ax.axhline(0.5,c='k')
  plt.legend()
  param_str = "-".join(["%s_%.3f"%(i,j) for i,j in schargs.items()])
  plt.savefig('figures/scratch_folders/%i/acc-%s.jpg'%(tstamp,param_str))
  if close:
    plt.close('all')
  return None

# %%
ns = 5
dfL = []
condL = ['blocked','interleaved','early','middle','late']
for idx,p_val in enumerate(p_vals):
  print(idx/len(p_vals))
  
  args['sch'][p_name] = p_val  
  exp_batch_data = run_batch_exp_curr(ns,args,condL)
  ## acc
  batch_acc = unpack_acc(exp_batch_data) # curr,seeds,trials
  mean_acc = batch_acc.mean(1)
  test_acc = mean_acc[:,-40:].mean(1) # curr  
  
  ## save traces of EML for each param setting
  pltsave_macc(mean_acc[2:],args['sch'],labL=['E','M','L'])
  
  ## record
  gsD = {
    **schargs,
    **dict(zip(condL,test_acc))
  }
  dfL.append(gsD)
  
gsdf = pd.DataFrame(dfL)
# Out:
# 0.0
# 0.08333333333333333
# 0.16666666666666666
# 0.25
# 0.3333333333333333
# 0.4166666666666667
# 0.5
# 0.5833333333333334
# 0.6666666666666666
# 0.75
# 0.8333333333333334
# 0.9166666666666666

# %%
gsdf.to_csv('data/gsdf%i.csv'%tstamp)
gsdf ## test acc dataframe
# Out:
#     concentration  stickiness_wi  stickiness_bt  sparsity  pvar  lrate  \
# 0             0.1           5000              5      0.08     2    0.8
# 1             0.3           5000              5      0.08     2    0.8
# 2             0.5           5000              5      0.08     2    0.8
# 3             0.7           5000              5      0.08     2    0.8
# 4             0.9           5000              5      0.08     2    0.8
# 5             1.1           5000              5      0.08     2    0.8
# 6             1.3           5000              5      0.08     2    0.8
# 7             1.5           5000              5      0.08     2    0.8
# 8             1.7           5000              5      0.08     2    0.8
# 9             1.9           5000              5      0.08     2    0.8
# 10            2.1           5000              5      0.08     2    0.8
# 11            2.3           5000              5      0.08     2    0.8
#
#     lratep  decay_rate  blocked  interleaved    early   middle     late
# 0        1           1  0.52375      0.47875  0.51625  0.46000  0.51000
# 1        1           1  0.47625      0.50375  0.49625  0.45875  0.51000
# 2        1           1  0.49375      0.50375  0.55000  0.53875  0.49375
# 3        1           1  0.49375      0.43875  0.48000  0.51875  0.50875
# 4        1           1  0.50250      0.52000  0.51250  0.47750  0.52000
# 5        1           1  0.52875      0.52250  0.55125  0.51000  0.52000
# 6        1           1  0.50875      0.45625  0.47875  0.48250  0.46250
# 7        1           1  0.51625      0.45125  0.52125  0.51500  0.53625
# 8        1           1  0.54250      0.51750  0.50000  0.50375  0.52000
# 9        1           1  0.50125      0.54750  0.47125  0.53250  0.46875
# 10       1           1  0.49125      0.44875  0.50250  0.52750  0.48375
# 11       1           1  0.45750      0.51250  0.49875  0.49500  0.50875

# %%
BI = gsdf.blocked > gsdf.interleaved
BM = gsdf.blocked > gsdf.middle
MI = gsdf.middle > gsdf.interleaved
gsdf[BI&BM&MI]
# Out:
#    concentration  stickiness_wi  stickiness_bt  sparsity  pvar  lrate  lratep  \
# 6            1.3           5000              5      0.08     2    0.8       1
# 7            1.5           5000              5      0.08     2    0.8       1
#
#    decay_rate  blocked  interleaved    early  middle     late
# 6           1  0.50875      0.45625  0.47875  0.4825  0.46250
# 7           1  0.51625      0.45125  0.52125  0.5150  0.53625
